# %% [markdown]
# # 🔍📊 Filtragem de Dados

# %%
# Importando Biblioteca Pandas
import pandas as pd

# %%
dados = pd.read_csv('train.csv')

# %%
# Os 5 primeiros dados
dados.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket       Fare Cabin Embarked
# 0      0         A/5 21171     7.2500   NaN        S
# 1      0          PC 17599    71.2833   C85        C
# 2      0  STON/O2. 3101282  7925.0000   NaN        S
# 3      0            113803    53.1000  C123        S
# ...

# %%
# Os 5 últimos dados
dados.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
# Pegando dados das colunas solicitadas
dados[['Survived', 'Name', 'Sex']]
# Out:
#      Survived                                               Name     Sex
# 0           0                            Braund, Mr. Owen Harris    male
# 1           1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2           1                             Heikkinen, Miss. Laina  female
# 3           1       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4           0                           Allen, Mr. William Henry    male
# ..        ...                                                ...     ...
# 886         0                              Montvila, Rev. Juozas    male
# 887         1                       Graham, Miss. Margaret Edith  female
# 888         0           Johnston, Miss. Catherine Helen "Carrie"  female
# 889         1                              Behr, Mr. Karl Howell    male
# 890         0                                Dooley, Mr. Patrick    male
#
# [891 rows x 3 columns]

# %% [markdown]
# ---
#
# ## LOC

# %%
# Pegando dados da primeira linha
dados.head(1)
# Out:
#    PassengerId  Survived  Pclass                     Name   Sex   Age  SibSp  \
# 0            1         0       3  Braund, Mr. Owen Harris  male  22.0      1
#
#    Parch     Ticket  Fare Cabin Embarked
# 0      0  A/5 21171  7.25   NaN        S

# %% [markdown]
# - Esse método possui dois parâmetros:
#   - **Número de linhas:** passado da seguinte forma ``[ValorInicial:ValorFinal]``;
#   - **Nome das colunas:** passado via lista

# %%
# loc[Linhas, ['NomeColuna']]
dados.loc[20:40, ['Survived', 'Name', 'Sex', 'Age']]
# Out:
#     Survived                                               Name     Sex   Age
# 20         0                               Fynney, Mr. Joseph J    male  35.0
# 21         1                              Beesley, Mr. Lawrence    male  34.0
# 22         1                        McGowan, Miss. Anna "Annie"  female  15.0
# 23         1                       Sloper, Mr. William Thompson    male  28.0
# 24         0                      Palsson, Miss. Torborg Danira  female   8.0
# 25         1  Asplund, Mrs. Carl Oscar (Selma Augusta Emilia...  female  38.0
# 26         0                            Emir, Mr. Farred Chehab    male   NaN
# 27         0                     Fortune, Mr. Charles Alexander    male  19.0
# 28         1                      O'Dwyer, Miss. Ellen "Nellie"  female   NaN
# 29         0                                Todoroff, Mr. Lalio    male   NaN
# 30         0                           Uruchurtu, Don. Manuel E    male  40.0
# ...

# %%
# Pode também só informar o valor inicial e não informar o valor final no primeiro parâmetro
# A biblioteca Pandas entenderá que você quer do valor informado até o valor final
dados.loc[800: , ['Survived', 'Name', 'Sex', 'Age']]
# Out:
#      Survived                                         Name     Sex    Age
# 800         0                         Ponesell, Mr. Martin    male  34.00
# 801         1  Collyer, Mrs. Harvey (Charlotte Annie Tate)  female  31.00
# 802         1          Carter, Master. William Thornton II    male  11.00
# 803         1              Thomas, Master. Assad Alexander    male   0.42
# 804         1                      Hedman, Mr. Oskar Arvid    male  27.00
# ..        ...                                          ...     ...    ...
# 886         0                        Montvila, Rev. Juozas    male  27.00
# 887         1                 Graham, Miss. Margaret Edith  female  19.00
# 888         0     Johnston, Miss. Catherine Helen "Carrie"  female    NaN
# 889         1                        Behr, Mr. Karl Howell    male  26.00
# 890         0                          Dooley, Mr. Patrick    male  32.00
#
# [91 rows x 4 columns]

# %%
# Também posso não informar o valor inicial e informar somente o valor final
# A biblioteca Pandas entenderá que você quer do valor inicial até o valor informado de linhas
dados.loc[ :500, ['Survived', 'Name', 'Sex', 'Age']]
# Out:
#      Survived                                               Name     Sex   Age
# 0           0                            Braund, Mr. Owen Harris    male  22.0
# 1           1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 2           1                             Heikkinen, Miss. Laina  female  26.0
# 3           1       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 4           0                           Allen, Mr. William Henry    male  35.0
# ..        ...                                                ...     ...   ...
# 496         1                     Eustis, Miss. Elizabeth Mussey  female  54.0
# 497         0                    Shellard, Mr. Frederick William    male   NaN
# 498         0    Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female  25.0
# 499         0                                 Svensson, Mr. Olof    male  24.0
# 500         0                                   Calic, Mr. Petar    male  17.0
#
# [501 rows x 4 columns]

# %%
# Uma boa prática: criar uma variável com a nossa consulta
dados2 = dados.loc[ :500, ['Survived', 'Name', 'Sex', 'Age']]

# %%
dados2
# Out:
#      Survived                                               Name     Sex   Age
# 0           0                            Braund, Mr. Owen Harris    male  22.0
# 1           1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 2           1                             Heikkinen, Miss. Laina  female  26.0
# 3           1       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 4           0                           Allen, Mr. William Henry    male  35.0
# ..        ...                                                ...     ...   ...
# 496         1                     Eustis, Miss. Elizabeth Mussey  female  54.0
# 497         0                    Shellard, Mr. Frederick William    male   NaN
# 498         0    Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female  25.0
# 499         0                                 Svensson, Mr. Olof    male  24.0
# 500         0                                   Calic, Mr. Petar    male  17.0
#
# [501 rows x 4 columns]

# %% [markdown]
# ---
#
# ## ILOC

# %% [markdown]
# - Esse método possui dois parâmetros:
#   - **Número de linhas:** passado da seguinte forma ``[ValorInicial:ValorFinal]``;
#   - **Índice de colunas:** passado da seguinte forma ``[ÍndiceColunaInformada:ÍndiceColunaFinal+1]``:
#     - O Índice Final deve ser **coluna+1**, pois a última coluna informada será desconsiderada;
#     - Será informada até a coluna anterior da coluna informada.

# %%
# loc[Linhas, faixa índice colunas]
dados.iloc[10:20, 1:6]
# Out:
#     Survived  Pclass                                               Name  \
# 10         1       3                    Sandstrom, Miss. Marguerite Rut
# 11         1       1                           Bonnell, Miss. Elizabeth
# 12         0       3                     Saundercock, Mr. William Henry
# 13         0       3                        Andersson, Mr. Anders Johan
# 14         0       3               Vestrom, Miss. Hulda Amanda Adolfina
# 15         1       2                   Hewlett, Mrs. (Mary D Kingcome)
# 16         0       3                               Rice, Master. Eugene
# 17         1       2                       Williams, Mr. Charles Eugene
# 18         0       3  Vander Planke, Mrs. Julius (Emelia Maria Vande...
# 19         1       3                            Masselmani, Mrs. Fatima
#
#        Sex   Age
# 10  female   4.0
# 11  female  58.0
# 12    male  20.0
# 13    male  39.0
# 14  female  14.0
# 15  female  55.0
# 16    male   2.0
# 17    male   NaN
# ...

# %%
# Pegando informações da coluna informada até a última
dados.iloc[10:20, 10: ]
# Out:
#    Cabin Embarked
# 10    G6        S
# 11  C103        S
# 12   NaN        S
# 13   NaN        S
# 14   NaN        S
# 15   NaN        S
# 16   NaN        Q
# 17   NaN        S
# 18   NaN        S
# 19   NaN        C

# %%
# Agora pegando dados da primeira coluna até a coluna informada
dados.iloc[10:20, :6]
# Out:
#     PassengerId  Survived  Pclass  \
# 10           11         1       3
# 11           12         1       1
# 12           13         0       3
# 13           14         0       3
# 14           15         0       3
# 15           16         1       2
# 16           17         0       3
# 17           18         1       2
# 18           19         0       3
# 19           20         1       3
#
#                                                  Name     Sex   Age
# 10                    Sandstrom, Miss. Marguerite Rut  female   4.0
# 11                           Bonnell, Miss. Elizabeth  female  58.0
# 12                     Saundercock, Mr. William Henry    male  20.0
# 13                        Andersson, Mr. Anders Johan    male  39.0
# 14               Vestrom, Miss. Hulda Amanda Adolfina  female  14.0
# 15                   Hewlett, Mrs. (Mary D Kingcome)   female  55.0
# 16                               Rice, Master. Eugene    male   2.0
# ...
