# %% [markdown]
# # 📚 Manipulando Dados Gigantes
#
# > __OBSERVAÇÃO:__ é necessário baixar o arquivo compactado no site do **INEP** e descompactá-lo dentro da pasta 'dataset_ENEM_2023', pois os arquivos necessários para este módulo estão nesse dataset do **INEP**.
#
# - **Dataset:** [ENEM 2023](https://www.gov.br/inep/pt-br/acesso-a-informacao/dados-abertos/microdados/enem)

# %%
import pandas as pd

# %%
df = pd.read_csv('dataset_ENEM_2023/DADOS/MICRODADOS_ENEM_2023.csv', nrows= 1000, encoding='ISO-8859-1', sep=';')

# %%
df.head()
# Out:
#    NU_INSCRICAO  NU_ANO  TP_FAIXA_ETARIA TP_SEXO  TP_ESTADO_CIVIL  \
# 0  210059085136    2023               14       M                2
# 1  210059527735    2023               12       M                2
# 2  210061103945    2023                6       F                1
# 3  210060214087    2023                2       F                1
# 4  210059980948    2023                3       F                1
#
#    TP_COR_RACA  TP_NACIONALIDADE  TP_ST_CONCLUSAO  TP_ANO_CONCLUIU  TP_ESCOLA  \
# 0            1                 1                1               17          1
# 1            1                 0                1               16          1
# 2            1                 1                1                0          1
# 3            3                 1                2                0          2
# 4            3                 1                2                0          2
#
#    ...  Q016  Q017  Q018 Q019  Q020 Q021  Q022  Q023  Q024  Q025
# ...

# %%
# Vendo as colunas do nosso dataset
df.columns
# Out:
# Index(['NU_INSCRICAO', 'NU_ANO', 'TP_FAIXA_ETARIA', 'TP_SEXO',
#        'TP_ESTADO_CIVIL', 'TP_COR_RACA', 'TP_NACIONALIDADE', 'TP_ST_CONCLUSAO',
#        'TP_ANO_CONCLUIU', 'TP_ESCOLA', 'TP_ENSINO', 'IN_TREINEIRO',
#        'CO_MUNICIPIO_ESC', 'NO_MUNICIPIO_ESC', 'CO_UF_ESC', 'SG_UF_ESC',
#        'TP_DEPENDENCIA_ADM_ESC', 'TP_LOCALIZACAO_ESC', 'TP_SIT_FUNC_ESC',
#        'CO_MUNICIPIO_PROVA', 'NO_MUNICIPIO_PROVA', 'CO_UF_PROVA',
#        'SG_UF_PROVA', 'TP_PRESENCA_CN', 'TP_PRESENCA_CH', 'TP_PRESENCA_LC',
#        'TP_PRESENCA_MT', 'CO_PROVA_CN', 'CO_PROVA_CH', 'CO_PROVA_LC',
#        'CO_PROVA_MT', 'NU_NOTA_CN', 'NU_NOTA_CH', 'NU_NOTA_LC', 'NU_NOTA_MT',
#        'TX_RESPOSTAS_CN', 'TX_RESPOSTAS_CH', 'TX_RESPOSTAS_LC',
#        'TX_RESPOSTAS_MT', 'TP_LINGUA', 'TX_GABARITO_CN', 'TX_GABARITO_CH',
#        'TX_GABARITO_LC', 'TX_GABARITO_MT', 'TP_STATUS_REDACAO',
#        'NU_NOTA_COMP1', 'NU_NOTA_COMP2', 'NU_NOTA_COMP3', 'NU_NOTA_COMP4',
# ...

# %%
for i in df.columns:
    print(i)
# Out:
# NU_INSCRICAO
# NU_ANO
# TP_FAIXA_ETARIA
# TP_SEXO
# TP_ESTADO_CIVIL
# TP_COR_RACA
# TP_NACIONALIDADE
# TP_ST_CONCLUSAO
# TP_ANO_CONCLUIU
# TP_ESCOLA
# TP_ENSINO
# IN_TREINEIRO
# CO_MUNICIPIO_ESC
# NO_MUNICIPIO_ESC
# CO_UF_ESC
# SG_UF_ESC
# TP_DEPENDENCIA_ADM_ESC
# TP_LOCALIZACAO_ESC
# TP_SIT_FUNC_ESC
# CO_MUNICIPIO_PROVA
# NO_MUNICIPIO_PROVA
# CO_UF_PROVA
# SG_UF_PROVA
# TP_PRESENCA_CN
# TP_PRESENCA_CH
# TP_PRESENCA_LC
# TP_PRESENCA_MT
# CO_PROVA_CN
# CO_PROVA_CH
# CO_PROVA_LC
# CO_PROVA_MT
# NU_NOTA_CN
# NU_NOTA_CH
# NU_NOTA_LC
# NU_NOTA_MT
# TX_RESPOSTAS_CN
# TX_RESPOSTAS_CH
# TX_RESPOSTAS_LC
# TX_RESPOSTAS_MT
# TP_LINGUA
# TX_GABARITO_CN
# TX_GABARITO_CH
# TX_GABARITO_LC
# TX_GABARITO_MT
# TP_STATUS_REDACAO
# NU_NOTA_COMP1
# NU_NOTA_COMP2
# NU_NOTA_COMP3
# NU_NOTA_COMP4
# NU_NOTA_COMP5
# NU_NOTA_REDACAO
# Q001
# Q002
# Q003
# Q004
# Q005
# Q006
# Q007
# Q008
# Q009
# Q010
# Q011
# Q012
# Q013
# Q014
# Q015
# Q016
# Q017
# Q018
# Q019
# Q020
# Q021
# Q022
# Q023
# Q024
# Q025

# %%
# Dessa forma é mais performático
[n for n in df.columns]
# Out:
# ['NU_INSCRICAO',
#  'NU_ANO',
#  'TP_FAIXA_ETARIA',
#  'TP_SEXO',
#  'TP_ESTADO_CIVIL',
#  'TP_COR_RACA',
#  'TP_NACIONALIDADE',
#  'TP_ST_CONCLUSAO',
#  'TP_ANO_CONCLUIU',
#  'TP_ESCOLA',
#  'TP_ENSINO',
#  'IN_TREINEIRO',
#  'CO_MUNICIPIO_ESC',
#  'NO_MUNICIPIO_ESC',
#  'CO_UF_ESC',
#  'SG_UF_ESC',
#  'TP_DEPENDENCIA_ADM_ESC',
#  'TP_LOCALIZACAO_ESC',
#  'TP_SIT_FUNC_ESC',
#  'CO_MUNICIPIO_PROVA',
#  'NO_MUNICIPIO_PROVA',
#  'CO_UF_PROVA',
#  'SG_UF_PROVA',
#  'TP_PRESENCA_CN',
#  'TP_PRESENCA_CH',
#  'TP_PRESENCA_LC',
#  'TP_PRESENCA_MT',
#  'CO_PROVA_CN',
#  'CO_PROVA_CH',
#  'CO_PROVA_LC',
#  'CO_PROVA_MT',
#  'NU_NOTA_CN',
#  'NU_NOTA_CH',
#  'NU_NOTA_LC',
#  'NU_NOTA_MT',
#  'TX_RESPOSTAS_CN',
#  'TX_RESPOSTAS_CH',
#  'TX_RESPOSTAS_LC',
#  'TX_RESPOSTAS_MT',
#  'TP_LINGUA',
#  'TX_GABARITO_CN',
#  'TX_GABARITO_CH',
#  'TX_GABARITO_LC',
#  'TX_GABARITO_MT',
#  'TP_STATUS_REDACAO',
#  'NU_NOTA_COMP1',
#  'NU_NOTA_COMP2',
#  'NU_NOTA_COMP3',
#  'NU_NOTA_COMP4',
# ...

# %% [markdown]
# ---
#
# ## Método Chunksize
# - No Pandas, o parâmetro chunksize é utilizado ao ler arquivos grandes, permitindo processá-los em partes menores em vez de carregá-los completamente na memória.
# - Isso é útil para lidar com grandes volumes de dados sem consumir muitos recursos do sistema.
#
# ### Como funciona?
# - Quando você usa chunksize, o Pandas lê o arquivo em lotes (chunks), retornando um iterador que pode ser processado iterativamente.
#
# ### Vantagens do chunksize:
# ✔ Permite processar arquivos grandes sem estourar a memória RAM. <br>
# ✔ É útil para análise de dados em lotes. <br>
# ✔ Pode ser combinado com operações como concat() para montar o DataFrame completo, se necessário.

# %%
dfc = pd.read_csv('dataset_ENEM_2023/DADOS/MICRODADOS_ENEM_2023.csv', encoding='ISO-8859-1', sep=';', chunksize=1000000)

# %%
dfc

# %%
grupo = 0

for i in dfc:
    grupo +=1
    print(len(i))
# Out:
# 1000000
# 1000000
# 1000000
# 933955

# %%
grupo
# Out:
# 4
