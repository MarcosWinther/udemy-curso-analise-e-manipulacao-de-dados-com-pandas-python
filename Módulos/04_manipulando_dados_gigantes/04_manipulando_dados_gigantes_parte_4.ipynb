# %% [markdown]
# # 📚 Manipulando Dados Gigantes - Parte 4
#
# > __OBSERVAÇÃO:__ é necessário baixar o arquivo compactado no site do **INEP** e descompactá-lo dentro da pasta 'dataset_ENEM_2023', pois os arquivos necessários para este módulo estão nesse dataset do **INEP**.
#
# - **Dataset:** [ENEM 2023](https://www.gov.br/inep/pt-br/acesso-a-informacao/dados-abertos/microdados/enem)
#
#
# ## Selecionando Colunas

# %%
import pandas as pd

# %%
df = pd.read_csv('dataset_ENEM_2023/DADOS/MICRODADOS_ENEM_2023_REDUZIDO.csv')

# %%
df.head()
# Out:
#    NU_INSCRICAO  NU_ANO  TP_FAIXA_ETARIA TP_SEXO  TP_ESTADO_CIVIL  \
# 0  210059085136    2023               14       M                2
# 1  210059527735    2023               12       M                2
# 2  210061103945    2023                6       F                1
# 3  210060214087    2023                2       F                1
# 4  210059980948    2023                3       F                1
#
#    TP_COR_RACA  TP_NACIONALIDADE  TP_ST_CONCLUSAO  TP_ANO_CONCLUIU  TP_ESCOLA  \
# 0            1                 1                1               17          1
# 1            1                 0                1               16          1
# 2            1                 1                1                0          1
# 3            3                 1                2                0          2
# 4            3                 1                2                0          2
#
#    ...  Q016  Q017  Q018 Q019  Q020 Q021  Q022  Q023  Q024  Q025
# ...

# %%
[i for i in df.columns]
# Out:
# ['NU_INSCRICAO',
#  'NU_ANO',
#  'TP_FAIXA_ETARIA',
#  'TP_SEXO',
#  'TP_ESTADO_CIVIL',
#  'TP_COR_RACA',
#  'TP_NACIONALIDADE',
#  'TP_ST_CONCLUSAO',
#  'TP_ANO_CONCLUIU',
#  'TP_ESCOLA',
#  'TP_ENSINO',
#  'IN_TREINEIRO',
#  'CO_MUNICIPIO_ESC',
#  'NO_MUNICIPIO_ESC',
#  'CO_UF_ESC',
#  'SG_UF_ESC',
#  'TP_DEPENDENCIA_ADM_ESC',
#  'TP_LOCALIZACAO_ESC',
#  'TP_SIT_FUNC_ESC',
#  'CO_MUNICIPIO_PROVA',
#  'NO_MUNICIPIO_PROVA',
#  'CO_UF_PROVA',
#  'SG_UF_PROVA',
#  'TP_PRESENCA_CN',
#  'TP_PRESENCA_CH',
#  'TP_PRESENCA_LC',
#  'TP_PRESENCA_MT',
#  'CO_PROVA_CN',
#  'CO_PROVA_CH',
#  'CO_PROVA_LC',
#  'CO_PROVA_MT',
#  'NU_NOTA_CN',
#  'NU_NOTA_CH',
#  'NU_NOTA_LC',
#  'NU_NOTA_MT',
#  'TX_RESPOSTAS_CN',
#  'TX_RESPOSTAS_CH',
#  'TX_RESPOSTAS_LC',
#  'TX_RESPOSTAS_MT',
#  'TP_LINGUA',
#  'TX_GABARITO_CN',
#  'TX_GABARITO_CH',
#  'TX_GABARITO_LC',
#  'TX_GABARITO_MT',
#  'TP_STATUS_REDACAO',
#  'NU_NOTA_COMP1',
#  'NU_NOTA_COMP2',
#  'NU_NOTA_COMP3',
#  'NU_NOTA_COMP4',
# ...

# %%
# Criando uma lista com o nome das colunas que quero carregar
colunas = ['TP_FAIXA_ETARIA', 'TP_SEXO', 'TP_COR_RACA', 'TP_NACIONALIDADE']

# %%
colunas
# Out:
# ['TP_FAIXA_ETARIA', 'TP_SEXO', 'TP_COR_RACA', 'TP_NACIONALIDADE']

# %%
# Com o parâmatro usecols, já carrego um dataframe com as colunas que eu quero carregar do nosso dataset
df1 = pd.read_csv('dataset_ENEM_2023/DADOS/MICRODADOS_ENEM_2023.csv', sep=';', encoding='ISO-8859-1', usecols=colunas)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3933955 entries, 0 to 3933954
# Data columns (total 4 columns):
#  #   Column            Dtype
# ---  ------            -----
#  0   TP_FAIXA_ETARIA   int64
#  1   TP_SEXO           object
#  2   TP_COR_RACA       int64
#  3   TP_NACIONALIDADE  int64
# dtypes: int64(3), object(1)
# memory usage: 120.1+ MB

# %%
df1.head()
# Out:
#    TP_FAIXA_ETARIA TP_SEXO  TP_COR_RACA  TP_NACIONALIDADE
# 0               14       M            1                 1
# 1               12       M            1                 0
# 2                6       F            1                 1
# 3                2       F            3                 1
# 4                3       F            3                 1

# %%
df1.tail()
# Out:
#          TP_FAIXA_ETARIA TP_SEXO  TP_COR_RACA  TP_NACIONALIDADE
# 3933950               12       M            1                 1
# 3933951                1       F            1                 2
# 3933952                3       F            3                 1
# 3933953                2       M            1                 1
# 3933954                3       F            3                 1
